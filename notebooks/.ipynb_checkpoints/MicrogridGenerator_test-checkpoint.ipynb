# %%
from __future__ import division

import sys
sys.path.append('/Users/Gonzague/Documents/Python/ploutos/')
from ploutos import MicrogridGenerator as mg

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
m_gen=mg.MicrogridGenerator()

# %%
m_gen.generate_microgrid()
# Out:
#              Load
# 0      638.378871
# 1      926.518750
# 2      393.708370
# 3      586.215617
# 4      404.886210
# ...           ...
# 8755  3697.381126
# 8756  1340.098836
# 8757  2269.101551
# 8758  1797.148300
# 8759  1249.434133
#
# [8760 rows x 1 columns]
# 7426634
# {'capa': 2543.367808219178, 'pcharge': 635.8419520547945, 'pdischarge': 635.8419520547945, 'soc_max': 1, 'soc_min': 0.2, 'efficiency': 0.9, 'soc_0': 0.2, 'cost_cycle': 0.3}

# %%
m_gen.microgrids[0].parameters
# Out:
#       load  cost_loss_load  PV_rated_power  battery_soc_0  \
# 0  7426634           10000       6683970.6            0.2
#
#    battery_power_charge  battery_power_discharge  battery_capacity  \
# 0            635.841952               635.841952       2543.367808
#
#    battery_efficiency  battery_soc_min  battery_soc_max  battery_cost_cycle  \
# 0                 0.9              0.2                1                 0.3
#
#    grid_power_import  grid_power_export  grid_price_import  grid_price_export
# 0         8425.60751         8425.60751                0.3                  0

# %%
m_gen.microgrids[0].architecture
# Out:
# {'PV': 1, 'battery': 1, 'genset': 0, 'grid': 1}

# %%
m_gen.microgrids[0].baseline_rule_based()

# %%
m_gen.microgrids[0].baseline_linprog()

# %%
m_gen.microgrids[0].baseline_priority_list_update_status
# Out:
#       net_load  battery_soc
# 0          0.0          0.2
# 1          0.0          0.2
# 2          0.0          0.2
# 3          0.0          0.2
# 4          0.0          0.2
# ...        ...          ...
# 8732       0.0          0.2
# 8733       0.0          0.2
# 8734       0.0          0.2
# 8735       0.0          0.2
# 8736       0.0          0.2
#
# [8737 rows x 2 columns]

# %%
m_gen.microgrids[0].baseline_linprog_update_status
# Out:
#       net_load  battery_soc
# 0          0.0     0.200000
# 1          0.0     0.200000
# 2          0.0     0.200000
# 3          0.0     0.200000
# 4          0.0     0.200000
# ...        ...          ...
# 8732       0.0     0.823508
# 8733       0.0     0.793477
# 8734       0.0     0.761448
# 8735       0.0     0.733932
# 8736       0.0     0.708869
#
# [8737 rows x 2 columns]

# %%
m_gen.microgrids[0].baseline_priority_list_action
# Out:
#       pv_consummed  pv_curtailed  battery_charge  battery_discharge  \
# 0              0.0           0.0             0.0       0.000000e+00
# 1              0.0           0.0             0.0       0.000000e+00
# 2              0.0           0.0             0.0       0.000000e+00
# 3              0.0           0.0             0.0       0.000000e+00
# 4              0.0           0.0             0.0       0.000000e+00
# ...            ...           ...             ...                ...
# 8731           0.0           0.0             0.0       5.115908e-14
# 8732           0.0           0.0             0.0       0.000000e+00
# 8733           0.0           0.0             0.0       0.000000e+00
# 8734           0.0           0.0             0.0       0.000000e+00
# 8735           0.0           0.0             0.0       0.000000e+00
#
#       grid_import  grid_export  genset  load_not_matched
# 0      638.378871          0.0     0.0               0.0
# ...

# %%
m_gen.microgrids[0].baseline_linprog_action.iloc[:100].plot()

# %%
m_gen.microgrids[0].baseline_priority_list_action.iloc[:100].plot()

# %%
m_gen.microgrids[0].load.plot()

# %%
m_gen.microgrids[0].pv.plot()

# %%
#### PLOTS TO KEEP ####

# %%
m_gen.microgrids[0].baseline_priority_list_update_status.plot()
plt.show()

# %%
m_gen.microgrids[0].baseline_linprog_update_status.plot()
plt.show()

# %%
plt.plot(m_gen.microgrids[0].baseline_linprog_action.battery_discharge[:100])
plt.plot(m_gen.microgrids[0].baseline_linprog_action.battery_charge[:100])
plt.plot(m_gen.microgrids[0].baseline_linprog_action.genset[:100])
plt.plot(m_gen.microgrids[0].baseline_linprog_action.pv_consummed[:100])
plt.plot(m_gen.microgrids[0].baseline_linprog_update_status.battery_soc[:100]*100)
plt.show()

# %%
plt.plot(m_gen.microgrids[0].baseline_priority_list_action.battery_discharge[:100])
plt.plot(m_gen.microgrids[0].baseline_priority_list_action.battery_charge[:100])
plt.plot(m_gen.microgrids[0].baseline_priority_list_action.genset[:100])
plt.plot(m_gen.microgrids[0].baseline_priority_list_action.pv_consummed[:100])
plt.plot(m_gen.microgrids[0].baseline_priority_list_update_status.battery_soc[:100]*100)
plt.show()

# %%
plt.plot(m_gen.microgrids[0].baseline_linprog_cost.cost[:100])
plt.plot(m_gen.microgrids[0].baseline_priority_list_cost.cost[:100])
plt.show()

# %%
m_gen.microgrids[0].baseline_priority_list_cost
# Out:
#             cost
# 0       0.000000
# 1      31.477280
# 2     277.931367
# 3     277.931367
# 4     277.931367
# ...          ...
# 8732  390.254094
# 8733  390.254094
# 8734  298.715514
# 8735  288.134967
# 8736  288.134967
#
# [8737 rows x 1 columns]
